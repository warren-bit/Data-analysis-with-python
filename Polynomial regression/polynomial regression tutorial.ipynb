# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv")
df.head(20)
# Out:
#    sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
# dividing the dataset in two components x and y
X = df.iloc[:, 1:2].values
y = df.iloc[:, 2:3].values

# %%
X
# Out:
# array([[  0],
#        [ 20],
#        [ 40],
#        [ 60],
#        [ 80],
#        [100]], dtype=int64)

# %%
y
# Out:
# array([[2.0e-04],
#        [1.2e-03],
#        [6.0e-03],
#        [3.0e-02],
#        [9.0e-02],
#        [2.7e-01]])

# %%
# fitting liniear regression to the dataset
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,y)
y_hat = lr.predict(X)
print(y_hat)
# Out:
# [[-0.05086667]
#  [-0.00402667]
#  [ 0.04281333]
#  [ 0.08965333]
#  [ 0.13649333]
#  [ 0.18333333]]

# %%
# fitting polynomial regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=4)

x_poly = poly.fit_transform(X)

poly.fit(x_poly, y)
lr2 = LinearRegression()
lr2.fit(x_poly, y)
y_hat2 = lr2.predict(poly.fit_transform(X))
print(y_hat2)
# Out:
# [[ 4.61111118e-04]
#  [-1.05555554e-04]
#  [ 8.61111111e-03]
#  [ 2.73888889e-02]
#  [ 9.13055556e-02]
#  [ 2.69738889e-01]]

# %% [markdown]
# visualizing linear regression results

# %%
# regression plot
width  = 10
height = 8
plt.figure(figsize=(width,height))
plt.title("Linear Regression")
sns.regplot(x = "Temperature", y = "Pressure", data = df)
# Out:
# <AxesSubplot:title={'center':'Linear Regression'}, xlabel='Temperature', ylabel='Pressure'>

# %%
# plotting a distrinution plot of actual vs predicted values
plt.figure(figsize=(width,height))
ax1 = sns.distplot(x = y, color = "r", hist=False, label = "Actual values")
sns.distplot(x = y_hat, color = "b", hist=False, label = "Fitted values", ax = ax1)
plt.title("Actual vs Fitted values of Pressure")
plt.xlabel("Pressure")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Pressure')

# %% [markdown]
# Visualizing polynomial regression results

# %%
# regression plot
plt.figure(figsize = (width,height))
plt.scatter(X,y, color = "blue")

plt.plot(X, y_hat2, color = "red")
plt.xlabel("Temperature")
plt.ylabel("Pressure")
plt.title("Polynomial Regression")
plt.show()

# %%
# plotting a distrinution plot of actual vs predicted values
plt.figure(figsize=(width,height))
ax1 = sns.distplot(x = y, color = "r", hist=False, label = "Actual values")
sns.distplot(x = y_hat2, color = "b", hist=False, label = "Fitted values", ax = ax1)
plt.title("Actual vs Fitted values of Pressure")
plt.xlabel("Pressure")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Pressure')
